# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('TNIstudent.csv')
df = df.drop('Timestamp', axis=1)
df = df.rename(columns={'Gender เพศ':'Gender','Degree ระดับการศึกษา':'Degree','Major of Study สาขา':'Major','Year of Birth ปีเกิด':'Age','Mode of Transportation วิธีการเดินทาง':'Transportation','Most favourite food shop in TNI ร้านอาหารที่ชอบในTNI':'TNIfoodshop','Most favourite food shop near TNI ร้านอาหารที่ชอบใกล้TNI':'nearTNIfoodshop','Most favourite beverage shop ร้านเครื่องดื่มที่ชอบ':'beverageshop','Most favourite vending machine ตู้กดอัตโนมัติที่ชอบ':'vendingmachine','Most Favourite Sport Facilities กีฬาที่ชอบ':'Sport','Most favourite spot to relax สถานที่พักผ่อนที่ชอบ':'relaxspot','Time spending in the library per week (hours) เวลาที่ใช้ในห้องสมุดต่อสัปดาห์':'hoursinthelibrary','study tools and Devices อุปกรณ์ที่ใช้ในการเรียนรู้':'studytools','Device Brand แบรนด์ของอุปกรณ์':'DeviceBrand','How do you spend per month คุณใช้จ่ายเท่าไรต่อเดือน':'Moneyspend','Type of accommodation รูปแบบที่พักอาศัย':'Typeofaccommodation','Opinions and Emotion มุมมองและความรู้สึก':'Emotion','Do you think the shops in the institute is expensive คุณคิดว่าสินค้าของร้านค้าในสถาบันมีราคาสูงหรือไม่':'ShopPrice','Stress from Study ความเครียดจากการเรียน':'StudyStress','Stress from Workload and Homework ความเครียดจากงานและการบ้าน':'HomworkStress','Stress from Social interaction ความเครียดจากสังคม':'StressformSocilaLife','Stress from Lecturer ความเครียดจากอาจารย์ผู้สอน':'StressfromLecturer','Stress from Family Situation ความเครียดจากครอบครัว':'FamilyStress','How satisfied with the job prospect of TNI คุณพึงพอใจกับโอกาสในการได้รับงานจากTNIหรือไม่':'HowsatisfiedwithTNI','How satisfied with the language proficiency in English and Japanese คุณพึงพอใจกับทักษะระดับภาษาอังกฤษและญี่ปุ่นขนาดไหน':'languageSatisfaction','How satisfied with the first aid room facility คุณพึงพอใจกับห้องปฐมพยาบาลหรือไม่':'AidroomSatisfaction','How satisfied with the library คุณพึงพอใจกับห้องสมุดขนาดไหน':'librarySatisfaction','How satisfied with the WiFi and Internet คุณพึงพอใจกับไวไฟและอินเตอร์เน็ตขนาดไหน':'WiFisatisfaction','Does cooperative shop has the item or goods you want สหกรณ์มีสินค้าที่คุณต้องการหรือไม่':'shopGoods','Overall opinion about TNI ความคิดเห็นเกี่ยวกับTNI':'OpinionaboutTNI','Are you satisfied with the speed of the printing services shop คุณพึงพอใจกับความเร็วของร้านถ่ายเอกสารหรือไม่':'PrintingSatisfaction'})
df.head()
# Out:
#         Gender                   Degree Major   Age Transportation  \
# 0     Male/ชาย  Undergraduate/ปริญญาตรี   DSA  2001  Walk เดินเท้า
# 1     Male/ชาย  Undergraduate/ปริญญาตรี   DGE  2004  Walk เดินเท้า
# 2  Female/หญิง  Undergraduate/ปริญญาตรี   JIB  2004     Car รถยนต์
# 3  Female/หญิง  Undergraduate/ปริญญาตรี   DSA  2002  Walk เดินเท้า
# 4  Female/หญิง  Undergraduate/ปริญญาตรี   DSA  2002  Walk เดินเท้า
#
#                                        TNIfoodshop  \
# 0         Hainanese chicken rice ข้าวมันไก่นายโส่ย
# 1  Hiramiya Japanese Food ร้านอาหารญี่ปุ่นฮิรามิยะ
# 2                            Snack shop ขนม-นม-เนย
# 3         Hainanese chicken rice ข้าวมันไก่นายโส่ย
# 4  Hiramiya Japanese Food ร้านอาหารญี่ปุ่นฮิรามิยะ
#
#                                      nearTNIfoodshop  \
# 0           Green Steak shop สเต็กคุณพีซ (ร้านเขียว)
# 1  Shop opposite blue building ร้านป้านิด (ร้านตร...
# 2                                               7-11
# ...

# %%
dithen={'Male/ชาย':'Male','Female/หญิง':'Female','LGBT/เพศทางเลือก':'LGBT','Prefer not to say/ไม่ระบุ':'NA',
        'Undergraduate/ปริญญาตรี':'Undergraduate','Master/ปริญญาโท':'Master',
        'Walk เดินเท้า':'Walk','Car รถยนต์':'Car','Public Transport การเดินทางสาธารณะ':'PublicTransport','Bicycle จักรยาน':'Bicycle','Motorbike จักรยานยนต์':'Motorbike',
        'Hainanese chicken rice ข้าวมันไก่นายโส่ย':'HainaneseChickenRice','Hiramiya Japanese Food ร้านอาหารญี่ปุ่นฮิรามิยะ':'HiramiyaJapaneseFood','Snack shop ขนม-นม-เนย':'SnackShop','Nima (Halal food) ร้านนิมา':'Nima(Halal food)','โอยาซึ (o yatsu)':'o yatsu','Kaizen ไข่เส้น':'Kaizen','Noodle shop ชิม ชาม นุ้ดเดิ้ล':'NoodleShop','Thai food shop ร้านคุณภา':'ThaiFoodShop','Fast food building D ป้ากาณจน์ ตึก D':'FastFoodBuildingD','Thai omlet shop building D ร้านข้าวไข่เจียวตึก D':'ThaiOmletShopBuildingD',
        'Blue shop behind 7-11 เลิศวิลัย (ร้านฟ้า)':'Blueshopbehind7-11','Green Steak shop สเต็กคุณพีซ (ร้านเขียว)':'GreenSteakshop','Kitty shop (japanese food) ร้านคิตตี้':'Kittyshop(japanese food)','Shop under blue building ร้านพี่นก (ร้านใต้ตึกฟ้า)':'Shopunderbluebuilding','Shop opposite blue building ร้านป้านิด (ร้านตรงข้ามตึกฟ้า)':'Shopoppositebluebuilding','Shop next to pink building ครัวเจ๊น้อย (ร้านข้างตึกชมพู)':'Shopnexttopinkbuilding','Beadouin steak and coffee เบดูอิน':'Beadouinsteakandcoffee','Noodle at soi 40 ก๋วยเตี๋ยวซอย40':'Noodleatsoi40','Food shop in front of soi 40 ร้านอาหารตามสั่งหน้าซอย40':'Foodshopinfrontofsoi40','Papaya salad at soi 40 ร้านส้มตำซอย40':'Papayasaladatsoi40',
        'Sunrise Coffee (Building A) ตึก A':'SunriseCoffeeBuilding A','Infinity/เอมุ (Building E) ตึก E':'InfinityBuilding E','Coffee Shop (Building B) ตึก B':'CoffeeShopBuilding B','Coffee Shop (Building D) ตึกD':'CoffeeShopBuilding D',
        'library ห้องสมุด':'library','E Building lounge เลานจ์ตึก E':'E Buildinglounge','M floor Building E ชั้นลอยตึก E':'M floor Building E','Vacant Classroom ห้องเรียนที่ว่าง':'Vacant Classroom','Lab แล็บ':'Lab','Creative Cultural Room Building E ห้องญี่ปุ่นตึก E':'Creative Cultural Room Building E',
        'less than 1 น้อยกว่า 1':'less than 1','More than 20 (มากกว่า 20 ชั่วโมง)':'More than 20',
        'less than 3,000 น้อยกว่า3,000':'less than 3,000','more than 10,000 มากกว่า10,000':'more than 10,000',
        'Dormitory หอพัก':'Dormitory','Condominium คอนโดมิเนียม':'Condominium','Detached House บ้านเดี่ยว':'Detached House','Apartment อพาร์ทเม้นท์':'Apartment','Town house ทาวน์เฮ้าส์':'Town house','Town home ทาวน์โฮม':'Town home',
        'No Stress ไม่เครียด':'No Stress','Very Stressful เครียดมาก':'Very Stressful',
        'Not Satisfied ไม่พึงพอใจ':'Not Satisfied','Fully Satisfied พึงพอใจเป็นอย่างยิ่ง':'Fully Satisfied',
        'Always มีตลอดเวลา':'Always','Sometimes บางครั้ง':'Sometimes','Never ไม่เคย':'Never'}
df['Gender'].replace(dithen, inplace=True)
df['Degree'].replace(dithen, inplace=True)
df['Age']=2022-df['Age']
df['Transportation'].replace(dithen, inplace=True)
df['TNIfoodshop'].replace(dithen, inplace=True)
df['nearTNIfoodshop'].replace(dithen, inplace=True)
df['beverageshop'].replace(dithen, inplace=True)
df['relaxspot'].replace(dithen, inplace=True)
df['hoursinthelibrary'].replace(dithen, inplace=True)
df['Moneyspend'].replace(dithen, inplace=True)
df['Typeofaccommodation'].replace(dithen, inplace=True)
df['shopGoods'].replace(dithen, inplace=True)
df.head()
# Out:
#    Gender         Degree Major  Age Transportation           TNIfoodshop  \
# 0    Male  Undergraduate   DSA   21           Walk  HainaneseChickenRice
# 1    Male  Undergraduate   DGE   18           Walk  HiramiyaJapaneseFood
# 2  Female  Undergraduate   JIB   18            Car             SnackShop
# 3  Female  Undergraduate   DSA   20           Walk  HainaneseChickenRice
# 4  Female  Undergraduate   DSA   20           Walk  HiramiyaJapaneseFood
#
#             nearTNIfoodshop             beverageshop vendingmachine  \
# 0            GreenSteakshop       InfinityBuilding E           7-11
# 1  Shopoppositebluebuilding       InfinityBuilding E           7-11
# 2                      7-11     CoffeeShopBuilding B           7-11
# 3            GreenSteakshop     CoffeeShopBuilding B           7-11
# 4     Shopunderbluebuilding  SunriseCoffeeBuilding A           7-11
#
#                       Sport  ... StressfromLecturer FamilyStress  \
# ...

# %%
# Defining the labels
my_labels = 'Male', 'Female', 'Prefer not to say', 'LGBT'
# Plotting the pie chart for above dataframe
plt.pie(df['Gender'].value_counts(), labels=my_labels, autopct='%1.1f%%', startangle=15)
plt.show()

# %%
df['FamilyStress'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Age = df['Age']
Major = df['Major']

# %%
plt.bar(Age,Major, color='y')
plt.show()

# %%
df['WiFisatisfaction'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import seaborn as sb

# %%
sns.scatterplot(x=df['WiFisatisfaction'], y=df['Major'])
# Out:
# <AxesSubplot:xlabel='WiFisatisfaction', ylabel='Major'>

# %%
df0 = df.corr()
df0
# Out:
#                            Age  ShopPrice  StudyStress  HomworkStress  \
# Age                   1.000000   0.106788     0.212141       0.149382
# ShopPrice             0.106788   1.000000     0.202311       0.175778
# StudyStress           0.212141   0.202311     1.000000       0.227052
# HomworkStress         0.149382   0.175778     0.227052       1.000000
# StressformSocilaLife -0.184134  -0.153374     0.206436       0.533819
# StressfromLecturer    0.220125   0.315366     0.652675       0.521274
# FamilyStress         -0.029124   0.078167     0.668394       0.219228
# HowsatisfiedwithTNI   0.012873   0.146540    -0.105269      -0.316888
# languageSatisfaction -0.296076  -0.067909    -0.376930      -0.421644
# AidroomSatisfaction   0.191690   0.266113    -0.342067       0.080290
# librarySatisfaction   0.236525   0.218903    -0.103989       0.160398
# WiFisatisfaction      0.310479   0.274286     0.210960       0.296684
# ...

# %%
ax = sns.heatmap(
    df0, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
sns.set_context("talk", font_scale=1.2)
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age',
                y='Major',
                # size="body_mass_g",
                sizes=(20, 500),
                alpha=0.5,
                hue='Gender',
                data=df)
  
# Put the legend out of the figure
plt.legend(bbox_to_anchor=(1.01, 1), borderaxespad=0)
  
# Put the legend out of the figure
plt.xlabel("Age")
plt.ylabel("Major")
plt.title("Bubble plot with Colors in Seaborn")
plt.tight_layout()

# %%
df.boxplot(by ='Major', column =['WiFisatisfaction'], grid = False)
# Out:
# <AxesSubplot:title={'center':'WiFisatisfaction'}, xlabel='Major'>

# %%
sns.set_style("whitegrid")
  
sns.boxplot(x = 'Major', y = 'WiFisatisfaction', data = df)
# Out:
# <AxesSubplot:xlabel='Major', ylabel='WiFisatisfaction'>

# %%
sns.barplot(data = df,x = 'Major', y = 'WiFisatisfaction')
# Out:
# <AxesSubplot:xlabel='Major', ylabel='WiFisatisfaction'>

# %%
sns.displot(data = df,x = 'Major', y = 'WiFisatisfaction')
